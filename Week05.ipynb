# %% [markdown]
# <a href="https://colab.research.google.com/github/kosyunderbar/kosy_underbar/blob/main/Week05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

sr = pd.Series([100, 200, 300, 400])
sr.index = ['A', 'B', 'O', 'AB']
sr
# Out:
# A     100
# B     200
# O     300
# AB    400
# dtype: int64

# %%
sr1 = pd.Series([10, 20, 30])
sr1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({'키' : [170, 180, 175], '몸무게' : [65, 78, 70]})
df.index = ['스파이더맨', '닥터스트레인지', '아이언맨']
df
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df = pd.read_csv('/content/sample_data/scores.csv', encoding='cp949')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.head() # .head(n) : 상위 n개 행 보기 (n을 생략하면 디폴트 5개 출력)
# Out:
#        이름     국어   영어     수학
# 0    tony  100.0   90   95.0
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
df.tail() # .tail(n) : 하위 n개 행 보기
# Out:
#         이름     국어   영어    수학
# 5      tor   70.0   75  65.0
# 6    bruce   80.0   90  55.0
# 7     thor   50.0   60   NaN
# 8  steaven  100.0  100  90.0
# 9    wanda   90.0   95  70.0

# %%
df.sample(3) # 랜덤 n개 행 보기
# Out:
#         이름     국어   영어    수학
# 6    bruce   80.0   90  55.0
# 4    scott    NaN   35  60.0
# 8  steaven  100.0  100  90.0

# %%
df.info() # 데이터프레임의 전반적인 정보 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     object
#  1   국어      9 non-null      float64
#  2   영어      10 non-null     int64
#  3   수학      9 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df.shape # 데이터프레임의 행, 열의 크기 출력
# Out:
# (10, 4)

# %%
len(df) # 데이터프레임의 행의 크기 출력
# Out:
# 10

# %%
df.isnull().sum() # 데이터프레임의 컬럼 별 결측치의 개수 추출 -> 결측치 : missing value
# Out:
# 이름    0
# 국어    1
# 영어    0
# 수학    1
# dtype: int64

# %%
df_dropna = df.dropna() # 결측값이 들어간 행 삭제
df_dropna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df_fillna = df.fillna(50) # 결측값을 fillna(n)의 n값으로 대체
df_fillna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott   50.0   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60   50.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.describe() # 숫자형 데이터의 요약통계 보기
# Out:
#                국어          영어          수학
# count    9.000000   10.000000    9.000000
# mean    86.111111   82.500000   78.888889
# std     16.914819   21.114766   17.638342
# min     50.000000   35.000000   55.000000
# 25%     80.000000   76.250000   65.000000
# 50%     90.000000   90.000000   75.000000
# 75%    100.000000   98.750000   95.000000
# max    100.000000  100.000000  100.000000

# %%
df['국어'].sum() # sum 합계
# Out:
# 775.0

# %%
df.value_counts('영어') # 컬럼별 값의 개수
# Out:
# 영어
# 100    3
# 90     2
# 35     1
# 60     1
# 75     1
# 80     1
# 95     1
# dtype: int64

# %%
df['국어'] # 한 개의 컬럼을 Series 형태로 추출 ex) df['이름']
# Out:
# 0    100.0
# 1     90.0
# 2     95.0
# 3    100.0
# 4      NaN
# 5     70.0
# 6     80.0
# 7     50.0
# 8    100.0
# 9     90.0
# Name: 국어, dtype: float64

# %%
df[['국어', '영어']]
# Out:
#       국어   영어
# 0  100.0   90
# 1   90.0   80
# 2   95.0  100
# 3  100.0  100
# 4    NaN   35
# 5   70.0   75
# 6   80.0   90
# 7   50.0   60
# 8  100.0  100
# 9   90.0   95

# %%
df.loc[1] # 특정 행의 모든 컬럼 추출
# Out:
# 이름     sam
# 국어    90.0
# 영어      80
# 수학    75.0
# Name: 1, dtype: object

# %%
df.loc[[1, 2, 3]]
# Out:
#        이름     국어   영어     수학
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0

# %%
df.iloc[2]
# Out:
# 이름    vision
# 국어      95.0
# 영어       100
# 수학     100.0
# Name: 2, dtype: object

# %%
df.iloc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
df.loc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0
# 5     tor   70.0   75   65.0

# %%
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.iloc[1, 3]
# Out:
# 75.0

# %%
df.iloc[1:3, 1:3]
# Out:
#      국어   영어
# 1  90.0   80
# 2  95.0  100
